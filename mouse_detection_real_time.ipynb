# %%
import torch
import numpy as np
import cv2
from time import time

# %%
class MouseDetector:
    

    def __init__(self, capture_index, model_name):
        """
        hangi kamerayı kullancağımız, hangi modeli kullanacağımız ekran kartı mı yoksa işlemci mi kullanacağız
        ve bazı değişkenlere atama yapıyoruz
        """
        self.capture_index = capture_index
        self.model = self.load_model(model_name)
        self.classes = self.model.names
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print("Using Device: ", self.device)

    def get_video_capture(self):
        """
        kameradan görüntü alıyoruz
        """
      
        return cv2.VideoCapture(self.capture_index)

    def load_model(self, model_name):
        """
        Pytorch hub'dan Yolov5 modelini indiriyoruz
        ve bunu modüle geri döndürüyoruz 
        """
        if model_name:
            model = torch.hub.load('ultralytics/yolov5', 'custom', path=model_name, force_reload=True)
        else:
            model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
        return model

    def score_frame(self, frame):
        """
        kameradan aldığı görüntüyü modele sokarak ondan tahmin oranı alıyoruz 
        """
        self.model.to(self.device)
        frame = [frame]
        results = self.model(frame)
        labels, cord = results.xyxyn[0][:, -1], results.xyxyn[0][:, :-1]
        return labels, cord

    def class_to_label(self, x):
        """
        classlarımızı labela dönüştürüyoruz.
        """
        return self.classes[int(x)]

    def plot_boxes(self, results, frame):
        """
        aranan objenin hangi konumlar içinde olduğunu buluyoruz.
        """
        labels, cord = results
        n = len(labels)
        x_shape, y_shape = frame.shape[1], frame.shape[0]
        for i in range(n):
            row = cord[i]
            if row[4] >= 0.3:
                x1, y1, x2, y2 = int(row[0]*x_shape), int(row[1]*y_shape), int(row[2]*x_shape), int(row[3]*y_shape)
                bgr = (0, 255, 0)
                cv2.rectangle(frame, (x1, y1), (x2, y2), bgr, 2)
                cv2.putText(frame, self.class_to_label(labels[i]), (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, bgr, 2)
                

        return frame

    def __call__(self):
        
        """
        kameramızı açarak aranan nesnenin nerede olduğunu hangi nesne olduğunu ve % kaç olasılıkla onun olduğunu yazıyoruz.
        """
        cap = self.get_video_capture()
        assert cap.isOpened()
      
        while True:
              
            ret, frame = cap.read()
            assert ret
            
            frame = cv2.resize(frame, (640,640))
            
            start_time = time()
            results = self.score_frame(frame)
            frame = self.plot_boxes(results, frame)
            
            end_time = time()
            fps = 1/np.round(end_time - start_time, 2)
            #print(f"her saniye frame yaz : {fps}")
             
            cv2.putText(frame, f'FPS: {int(fps)}', (20,70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
            
            cv2.imshow('YOLOv5 Detection', frame)
 
            if cv2.waitKey(5) & 0xFF == ord('q'):
                break
      
        cap.release()
        cv2.destroyAllWindows()
        
# yeni bir obje oluşturarak çalıştırıyoruz.

detector = MouseDetector(capture_index=0, model_name='best.pt')
detector()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Merve/.cache\torch\hub\master.zip
# requirements: Ultralytics requirement ['Pillow>=10.0.1'] not found, attempting AutoUpdate...
# requirements:  Command 'pip install --no-cache "Pillow>=10.0.1"  ' returned non-zero exit status 1.
# YOLOv5  2023-12-24 Python-3.9.16 torch-2.0.1 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...
# Using Device:  cpu

# %%
# %pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.138-py3-none-any.whl (605 kB)
#      ---------------------------------------- 0.0/605.5 kB ? eta -:--:--
#      - ------------------------------------- 30.7/605.5 kB 1.3 MB/s eta 0:00:01
#      ------- ------------------------------ 112.6/605.5 kB 1.1 MB/s eta 0:00:01
#      ---------- --------------------------- 174.1/605.5 kB 1.2 MB/s eta 0:00:01
#      -------------- ----------------------- 235.5/605.5 kB 1.4 MB/s eta 0:00:01
#      ----------------------- -------------- 368.6/605.5 kB 1.6 MB/s eta 0:00:01
#      -------------------------------- ----- 512.0/605.5 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 605.5/605.5 kB 2.1 MB/s eta 0:00:00
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl (38.1 MB)
#      ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#      ---------------------------------------- 0.5/38.1 MB 9.6 MB/s eta 0:00:04
#       --------------------------------------- 0.7/38.1 MB 8.5 MB/s eta 0:00:05
#      - -------------------------------------- 1.2/38.1 MB 9.2 MB/s eta 0:00:05
#      - -------------------------------------- 1.7/38.1 MB 9.8 MB/s eta 0:00:04
#      -- ------------------------------------- 2.2/38.1 MB 10.0 MB/s eta 0:00:04
#      -- ------------------------------------- 2.5/38.1 MB 9.8 MB/s eta 0:00:04
#      -- ------------------------------------- 2.5/38.1 MB 9.8 MB/s eta 0:00:04
#      -- ------------------------------------- 2.5/38.1 MB 9.8 MB/s eta 0:00:04
#      --- ------------------------------------ 3.1/38.1 MB 7.5 MB/s eta 0:00:05
#      ---- ----------------------------------- 3.9/38.1 MB 8.6 MB/s eta 0:00:04
#      ----- ---------------------------------- 5.2/38.1 MB 10.4 MB/s eta 0:00:04
#      ----- ---------------------------------- 5.6/38.1 MB 10.5 MB/s eta 0:00:04
#      ------ --------------------------------- 6.1/38.1 MB 10.2 MB/s eta 0:00:04
#      ------ --------------------------------- 6.6/38.1 MB 10.2 MB/s eta 0:00:04
#      ------- -------------------------------- 7.1/38.1 MB 10.3 MB/s eta 0:00:04
#      ------- -------------------------------- 7.3/38.1 MB 10.4 MB/s eta 0:00:03
#      ------- -------------------------------- 7.3/38.1 MB 10.4 MB/s eta 0:00:03
#      ------- -------------------------------- 7.3/38.1 MB 10.4 MB/s eta 0:00:03
#      --------- ------------------------------ 8.7/38.1 MB 10.0 MB/s eta 0:00:03
#      --------- ------------------------------ 8.8/38.1 MB 10.0 MB/s eta 0:00:03
#      ---------- ---------------------------- 10.1/38.1 MB 10.5 MB/s eta 0:00:03
#      ---------- ---------------------------- 10.6/38.1 MB 10.4 MB/s eta 0:00:03
#      ----------- --------------------------- 11.1/38.1 MB 10.7 MB/s eta 0:00:03
#      ----------- --------------------------- 11.6/38.1 MB 10.6 MB/s eta 0:00:03
#      ------------ -------------------------- 12.1/38.1 MB 10.7 MB/s eta 0:00:03
#      ------------ -------------------------- 12.6/38.1 MB 10.6 MB/s eta 0:00:03
#      ------------- ------------------------- 13.1/38.1 MB 12.1 MB/s eta 0:00:03
#      ------------- ------------------------- 13.6/38.1 MB 11.9 MB/s eta 0:00:03
#      -------------- ------------------------ 14.0/38.1 MB 11.7 MB/s eta 0:00:03
#      -------------- ------------------------ 14.6/38.1 MB 11.1 MB/s eta 0:00:03
#      --------------- ----------------------- 15.0/38.1 MB 10.7 MB/s eta 0:00:03
#      --------------- ----------------------- 15.6/38.1 MB 10.7 MB/s eta 0:00:03
#      ---------------- ---------------------- 15.7/38.1 MB 10.7 MB/s eta 0:00:03
#      ---------------- ---------------------- 15.8/38.1 MB 10.1 MB/s eta 0:00:03
#      ---------------- ---------------------- 16.3/38.1 MB 10.1 MB/s eta 0:00:03
#      ---------------- ---------------------- 16.4/38.1 MB 10.1 MB/s eta 0:00:03
#      ---------------- ---------------------- 16.4/38.1 MB 10.1 MB/s eta 0:00:03
#      ---------------- ---------------------- 16.4/38.1 MB 10.1 MB/s eta 0:00:03
#      ----------------- ---------------------- 16.8/38.1 MB 8.8 MB/s eta 0:00:03
#      ------------------ -------------------- 17.7/38.1 MB 10.4 MB/s eta 0:00:02
#      ------------------ -------------------- 18.1/38.1 MB 10.1 MB/s eta 0:00:02
#      ------------------- -------------------- 18.6/38.1 MB 9.6 MB/s eta 0:00:03
#      -------------------- ------------------- 19.1/38.1 MB 9.8 MB/s eta 0:00:02
#      -------------------- ------------------- 19.6/38.1 MB 9.4 MB/s eta 0:00:02
#      --------------------- ------------------ 20.0/38.1 MB 9.0 MB/s eta 0:00:03
#      --------------------- ------------------ 20.6/38.1 MB 9.0 MB/s eta 0:00:02
#      ---------------------- ----------------- 21.0/38.1 MB 9.1 MB/s eta 0:00:02
#      ---------------------- ----------------- 21.5/38.1 MB 9.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 22.0/38.1 MB 9.0 MB/s eta 0:00:02
#      ----------------------- ---------------- 22.4/38.1 MB 9.0 MB/s eta 0:00:02
#      ------------------------ --------------- 22.9/38.1 MB 9.0 MB/s eta 0:00:02
#      ------------------------ --------------- 23.3/38.1 MB 9.0 MB/s eta 0:00:02
#      ------------------------- -------------- 23.9/38.1 MB 9.0 MB/s eta 0:00:02
#      ------------------------- -------------- 24.4/38.1 MB 9.0 MB/s eta 0:00:02
#      -------------------------- ------------- 24.8/38.1 MB 8.8 MB/s eta 0:00:02
#      -------------------------- ------------- 25.1/38.1 MB 8.8 MB/s eta 0:00:02
#      -------------------------- ------------- 25.5/38.1 MB 8.7 MB/s eta 0:00:02
#      --------------------------- ------------ 26.1/38.1 MB 9.2 MB/s eta 0:00:02
#      --------------------------- ------------ 26.4/38.1 MB 9.1 MB/s eta 0:00:02
#      --------------------------- ----------- 26.9/38.1 MB 10.4 MB/s eta 0:00:02
#      --------------------------- ----------- 27.3/38.1 MB 10.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 27.8/38.1 MB 9.9 MB/s eta 0:00:02
#      ----------------------------- ---------- 28.2/38.1 MB 9.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 28.5/38.1 MB 9.8 MB/s eta 0:00:01
#      ------------------------------ --------- 29.0/38.1 MB 9.8 MB/s eta 0:00:01
#      ------------------------------ --------- 29.4/38.1 MB 9.6 MB/s eta 0:00:01
#      ------------------------------- -------- 29.9/38.1 MB 9.6 MB/s eta 0:00:01
#      ------------------------------- -------- 30.2/38.1 MB 9.5 MB/s eta 0:00:01
#      -------------------------------- ------- 30.6/38.1 MB 9.5 MB/s eta 0:00:01
#      -------------------------------- ------- 31.0/38.1 MB 9.5 MB/s eta 0:00:01
#      --------------------------------- ------ 31.4/38.1 MB 9.5 MB/s eta 0:00:01
#      --------------------------------- ------ 31.8/38.1 MB 9.4 MB/s eta 0:00:01
#      --------------------------------- ------ 32.1/38.1 MB 9.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 32.6/38.1 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 33.0/38.1 MB 9.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 33.5/38.1 MB 9.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 33.9/38.1 MB 9.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 33.9/38.1 MB 9.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 34.2/38.1 MB 8.6 MB/s eta 0:00:01
#      ------------------------------------ --- 34.6/38.1 MB 8.6 MB/s eta 0:00:01
#      ------------------------------------ --- 35.1/38.1 MB 8.6 MB/s eta 0:00:01
#      ------------------------------------- -- 35.6/38.1 MB 8.7 MB/s eta 0:00:01
#      ------------------------------------- -- 36.1/38.1 MB 8.7 MB/s eta 0:00:01
#      -------------------------------------- - 36.6/38.1 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------  37.1/38.1 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------  37.6/38.1 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------  38.1/38.1 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------  38.1/38.1 MB 8.8 MB/s eta 0:00:01
#      ---------------------------------------- 38.1/38.1 MB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (0.15.2)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: psutil in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (2.29.0)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      -------------------------------------- 293.3/293.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: torch>=1.7.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from ultralytics) (2.0.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (5.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: filelock in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from torch>=1.7.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from torch>=1.7.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from torch>=1.7.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from torch>=1.7.0->ultralytics) (3.1.2)
# Requirement already satisfied: colorama in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->ultralytics) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from jinja2->torch>=1.7.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\merve\anaconda3\envs\dsp\lib\site-packages (from sympy->torch>=1.7.0->ultralytics) (1.3.0)
# Installing collected packages: opencv-python, seaborn, ultralytics
# Successfully installed opencv-python-4.8.0.74 seaborn-0.12.2 ultralytics-8.0.138
# Note: you may need to restart the kernel to use updated packages.
